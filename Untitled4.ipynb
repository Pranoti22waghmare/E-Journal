# %%
import numpy as np
import pandas as pd

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %%
sales = np.array([200,290,280,300,220])
sales
# Out:
# array([200, 290, 280, 300, 220])

# %%
plot_acf(sales)

# %%
L = np.log(sales)
L
# Out:
# array([5.29831737, 5.66988092, 5.6347896 , 5.70378247, 5.39362755])

# %%
plot_acf(L)
